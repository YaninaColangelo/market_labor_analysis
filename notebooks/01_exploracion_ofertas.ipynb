# %% [markdown]
# # 01 - Exploracion de ofertas
#
# Prueba minima del pipeline: conector, oferta_raw, ETL, DataFrame, CSV y carga opcional en MySQL.

# %%
from pathlib import Path
import sys

import pandas as pd

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT))

# %%
from src.connectors.tecnoempleo import obtener_oferta
from src.database import cargar_mysql, leer_ofertas
from src.etl import transformar_oferta
from src.utils import DATA_PROCESSED, guardar_csv

# %%
url = 'PEGAR_URL_REAL_DE_TECNOEMPLEO'

oferta_raw = obtener_oferta(url)
oferta_raw

# %%
oferta_clean = transformar_oferta(oferta_raw)
df = pd.DataFrame([oferta_clean])
df

# %%
csv_path = DATA_PROCESSED / 'oferta_tecnoempleo.csv'
guardar_csv(df, csv_path)
csv_path

# %%
# Requiere configurar MYSQL_DATABASE_URL o las variables MYSQL_USER, MYSQL_PASSWORD,
# MYSQL_HOST, MYSQL_PORT y MYSQL_DATABASE en un archivo .env.
# cargar_mysql(df)
# leer_ofertas(limit=5)
