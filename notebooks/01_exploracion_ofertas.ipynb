# %% [markdown]
# # 01 - Exploracion de ofertas
#
# Objetivo: revisar la estructura inicial de las ofertas, detectar campos incompletos y observar primeras señales sobre necesidades organizacionales.

# %%
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
raw_path = PROJECT_ROOT / 'data' / 'raw' / 'ofertas_brutas.csv'
df = pd.read_csv(raw_path)
df.head()

# %%
df.info()

# %%
df[['pais', 'industria', 'seniority', 'modalidad']].value_counts(dropna=False)
